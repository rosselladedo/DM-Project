# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import math
from tqdm.notebook import tqdm

# %%
df = pd.read_csv('../dataset/new_Basket_3_2010.csv', sep=',')
df
# Out:
#                Country  Customer ID                        Description  \
# 0       United Kingdom      14590.0            RETRO SPOTS BUTTER DISH
# 1       United Kingdom      14590.0                     RETRO SPOT MUG
# 2       United Kingdom      14590.0          RETRO SPOT LARGE MILK JUG
# 3       United Kingdom      14590.0    NEW ENGLAND CERAMIC CAKE SERVER
# 4       United Kingdom      14590.0               HAND OPEN SHAPE GOLD
# ...                ...          ...                                ...
# 409828  United Kingdom      18116.0  SET OF 3 BUTTERFLY COOKIE CUTTERS
# 409829  United Kingdom      18116.0              HOT BATHS SOAP HOLDER
# 409830  United Kingdom      18116.0             FAIRY SOAP SOAP HOLDER
# 409831  United Kingdom      18116.0        CREAM SWEETHEART EGG HOLDER
# 409832  United Kingdom      18116.0                TEA TIME OVEN GLOVE
#
#         Invoice          InvoiceDate  Price  Quantity StockCode
# 0       C493411  2010-04-01 09:43:00   4.25        -1     21539
# 1        493414  2010-04-01 10:28:00   2.55        36     21844
# 2        493414  2010-04-01 10:28:00   4.25        12     21533
# 3        493414  2010-04-01 10:28:00   2.55         2     37508
# 4        493414  2010-04-01 10:28:00   4.25         2    35001G
# ...         ...                  ...    ...       ...       ...
# 409828   539988  2010-12-23 16:06:00   1.25         1     84380
# 409829   539988  2010-12-23 16:06:00   1.69         1    84849D
# 409830   539988  2010-12-23 16:06:00   1.69         1    84849B
# 409831   539988  2010-12-23 16:06:00   4.95         2     22854
# 409832   539988  2010-12-23 16:06:00   1.25         2    47559B
#
# [409833 rows x 8 columns]

# %%
data = pd.core.frame.DataFrame({'Customer ID' : df['Customer ID'].unique()})
data
# Out:
#       Customer ID
# 0         14590.0
# 1         13287.0
# 2         16550.0
# 3         14680.0
# 4         17372.0
# ...           ...
# 4215      16270.0
# 4216      12515.0
# 4217      12383.0
# 4218      13817.0
# 4219      12585.0
#
# [4220 rows x 1 columns]

# %%
d_aux=df[(df['Quantity']>0) | (df['StockCode']=='D')]
#mean cost of the products in the orders in the period of observation
MeanProdSale = d_aux.groupby('Customer ID',as_index=False)['Price'].mean()
MeanProdSale.columns = ['Customer ID', 'MeanProdSale']
MeanProdSale
# Out:
#       Customer ID  MeanProdSale
# 0         12346.0      6.814400
# 1         12347.0      2.475882
# 2         12348.0      0.656857
# 3         12349.0      4.253400
# 4         12351.0      2.355238
# ...           ...           ...
# 4211      18283.0      2.168783
# 4212      18284.0      3.253214
# 4213      18285.0      8.350000
# 4214      18286.0      3.012000
# 4215      18287.0      2.844588
#
# [4216 rows x 2 columns]

# %%
#distinct products
d_aux=df[df['StockCode']!='D']
distinctProd = d_aux.groupby('Customer ID',as_index=False)['StockCode'].nunique()
distinctProd.columns = ['Customer ID', 'DistinctProd']
distinctProd
# Out:
#       Customer ID  DistinctProd
# 0         12346.0            24
# 1         12347.0            70
# 2         12348.0            20
# 3         12349.0            89
# 4         12351.0            21
# ...           ...           ...
# 4215      18283.0           158
# 4216      18284.0            28
# 4217      18285.0            12
# 4218      18286.0            52
# 4219      18287.0            77
#
# [4220 rows x 2 columns]

# %%
#number of distinct session for Customer
d_aux=df[df['Quantity']>0]
Nsessions = d_aux.groupby('Customer ID')['Invoice'].nunique().reset_index()
Nsessions.columns = ['Customer ID', 'Nsessions']
Nsessions
# Out:
#       Customer ID  Nsessions
# 0         12346.0          2
# 1         12347.0          2
# 2         12348.0          2
# 3         12349.0          2
# 4         12351.0          1
# ...           ...        ...
# 4211      18283.0          6
# 4212      18284.0          1
# 4213      18285.0          1
# 4214      18286.0          1
# 4215      18287.0          4
#
# [4216 rows x 2 columns]

# %%
#Total amount spent
total_sale = []
total_prod_returned=[]
total_sale_wret=[]
total_products=[]
min_prod_spent=[]
max_prod_spent=[]   

for customer in tqdm(df['Customer ID'].unique(), total=len(df['Customer ID'].unique()), desc="Iterating over customers"):
    df_aux = df.loc[df['Customer ID'] == customer, ['Quantity', 'Price','StockCode']]
       
    mps = []
    ts=0
    tp=0
    tpr=0
    tswr=0
    for _, row in df_aux.iterrows():
        cost = row['Quantity']*row['Price']
        tp +=row['Quantity'] if row['StockCode']!='D' else 0
        ts += cost
        
        if row['Quantity']>0 or row['StockCode']=='D':
            tswr+=cost
            if row['Quantity'] >0: # not DISCOUNT
                mps.append(cost)
        
        else:
            tpr-=row['Quantity']
    
    total_sale.append(ts)
    total_products.append(tp)
    total_sale_wret.append(tswr)
    min_prod_spent.append(min(mps,default=0))
    max_prod_spent.append(max(mps,default=0))
    total_prod_returned.append(tpr)
# Out:
# HBox(children=(HTML(value='Iterating over customers'), FloatProgress(value=0.0, max=4220.0), HTML(value='')))

# %%
sessions_per_customer = {}
data_session = df[['Invoice','Customer ID']].drop_duplicates()

for _, r in tqdm(data_session.iterrows(), total=len(data_session), desc="Iterating over orders"):
    customer = r["Customer ID"]
    session = r["Invoice"]
    df_aux = df.loc[df['Invoice'] == session, ['Quantity','Price','StockCode', 'Customer ID']]
    df_aux = df_aux.loc[df['Customer ID'] == customer, ['Quantity','Price','StockCode']]
    temp_prod = 0
    temp_sale = 0 
    
    for _, int_r in df_aux.iterrows():
        temp_prod += int_r['Quantity']
        temp_sale += int_r['Quantity']*int_r['Price']
        
    if customer not in sessions_per_customer:
        sessions_per_customer[customer] = [0,0,0]
        
    sessions_per_customer[customer][0] += temp_prod
    sessions_per_customer[customer][1] += temp_sale
    sessions_per_customer[customer][2] += 1
# Out:
# HBox(children=(HTML(value='Iterating over orders'), FloatProgress(value=0.0, max=21680.0), HTML(value='')))

# %%
mean_spent_session_wise = []     # mean amount spent (by order) per customer
mean_products_session_wise = []  # mean number of products bought per shopping session per customer

for customer in tqdm(df['Customer ID'].unique(), total=len(df['Customer ID'].unique()), desc="Iterating over customers"): 
    mean_products_session_wise.append(sessions_per_customer[customer][0] / sessions_per_customer[customer][2])
    mean_spent_session_wise.append(sessions_per_customer[customer][1] / sessions_per_customer[customer][2])
# Out:
# HBox(children=(HTML(value='Iterating over customers'), FloatProgress(value=0.0, max=4220.0), HTML(value='')))

# %%
MeanTimeGap = df.groupby(['Customer ID', 'InvoiceDate'], as_index=False)['Invoice'].count()
MeanTimeGap.columns = ['Customer ID', 'InvoiceDate','MeanTimeGap']
MeanTimeGap
# Out:
#        Customer ID          InvoiceDate  MeanTimeGap
# 0          12346.0  2010-02-03 13:08:00            5
# 1          12346.0  2010-04-10 09:54:00            1
# 2          12346.0  2010-06-28 13:53:00           19
# 3          12347.0  2010-07-12 14:57:00           62
# 4          12347.0  2010-10-31 14:20:00           40
# ...            ...                  ...          ...
# 21585      18286.0  2010-08-20 11:57:00           50
# 21586      18287.0  2010-05-17 11:55:00           54
# 21587      18287.0  2010-09-21 12:17:00           19
# 21588      18287.0  2010-09-21 12:19:00            2
# 21589      18287.0  2010-11-22 11:51:00           10
#
# [21590 rows x 3 columns]

# %%
MeanTimeGap['InvoiceDate'] = pd.to_datetime(MeanTimeGap['InvoiceDate']).dt.date
def gapTime(MeanTimeGap):
    mean_time_gap=[]
    for customer in MeanTimeGap['Customer ID'].unique():
        df_aux=MeanTimeGap[MeanTimeGap['Customer ID']==customer]
        df_aux=df_aux['InvoiceDate'].to_list()
        sum_diff_gap = 0
        for i in range(0, len(df_aux)-1):
            sum_diff_gap += (df_aux[i+1]-df_aux[i]).days

        if len(df_aux)-1 == 0:
            mean_time_gap.append(0)
        else:
            mean_time_gap.append(sum_diff_gap / (len(df_aux)-1))
    return mean_time_gap

# %%
mean_time_gap=gapTime(MeanTimeGap)
customer_time=MeanTimeGap['Customer ID'].unique()
data_tuples = list(zip(customer_time,mean_time_gap))
MeanTime=pd.DataFrame(data_tuples, columns=['Customer ID','MeanTimeGap'])
MeanTime
# Out:
#       Customer ID  MeanTimeGap
# 0         12346.0         72.5
# 1         12347.0        111.0
# 2         12348.0         80.0
# 3         12349.0        182.0
# 4         12351.0          0.0
# ...           ...          ...
# 4215      18283.0         58.4
# 4216      18284.0          0.0
# 4217      18285.0          0.0
# 4218      18286.0         57.0
# 4219      18287.0         63.0
#
# [4220 rows x 2 columns]

# %%
df3=pd.merge(data,MeanProdSale, how='left')

# %%
df3['TotalSale']=total_sale
df3['TotalProd']=total_products
df3['MeanSpentSession']=mean_spent_session_wise
df3['MeanProdSession']=mean_products_session_wise
df3['TotalSpentRet']=total_sale_wret
df3['TotalProdRet']=total_prod_returned
df3['MinProdSpent']=min_prod_spent
df3['MaxProdSpent']=max_prod_spent

# %%
Customer_09 =df3.merge(MeanTime, on='Customer ID').set_index('Customer ID')

# %%
Customer_09.reset_index()
# Out:
#       Customer ID  MeanProdSale  TotalSale  TotalProd  MeanSpentSession  \
# 0         14590.0      4.068153    2592.13        783        117.824091
# 1         13287.0      3.054151     583.77        319         97.295000
# 2         16550.0      2.694926    6376.10       3888        335.584211
# 3         14680.0      2.829765   29393.66      13842        459.275938
# 4         17372.0      3.026513    2830.28       1157        134.775238
# ...           ...           ...        ...        ...               ...
# 4215      16270.0      3.222778    1141.24        688       1141.240000
# 4216      12515.0      4.900000     278.70        128        278.700000
# 4217      12383.0      0.945278     555.72        751        555.720000
# 4218      13817.0      1.900000     110.70         62        110.700000
# 4219      12585.0      2.589531    1154.85        866       1154.850000
#
#       MeanProdSession  TotalSpentRet  TotalProdRet  MinProdSpent  \
# 0           35.590909        2656.96            13          0.85
# 1           53.166667         781.59           110          7.50
# 2          204.631579        6614.85            49          1.05
# 3          216.281250       30213.83           345          0.84
# 4           55.095238        2882.41            49          0.21
# ...               ...            ...           ...           ...
# 4215       688.000000        1141.24             0         10.08
# 4216       128.000000         278.70             0          9.00
# 4217       751.000000         555.72             0          5.04
# 4218        62.000000         110.70             0         10.20
# 4219       866.000000        1154.85             0          6.96
#
#       MaxProdSpent  MeanTimeGap
# 0            100.8    14.619048
# 1             25.5    21.000000
# 2             90.0    15.705882
# 3            306.0     5.606557
# 4             76.5    15.850000
# ...            ...          ...
# 4215         102.0     0.000000
# 4216          25.5     0.000000
# 4217          47.4     0.000000
# 4218          19.5     0.000000
# 4219          91.8     0.000000
#
# [4220 rows x 11 columns]

# %%
Customer_x=pd.merge(Customer_09,Nsessions, how='left',on='Customer ID')

# %%
Customer_10=pd.merge(Customer_x,distinctProd,on='Customer ID')

# %%
Customer_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4220 entries, 0 to 4219
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer ID       4220 non-null   float64
#  1   MeanProdSale      4216 non-null   float64
#  2   TotalSale         4220 non-null   float64
#  3   TotalProd         4220 non-null   int64
#  4   MeanSpentSession  4220 non-null   float64
#  5   MeanProdSession   4220 non-null   float64
#  6   TotalSpentRet     4220 non-null   float64
#  7   TotalProdRet      4220 non-null   int64
#  8   MinProdSpent      4220 non-null   float64
#  9   MaxProdSpent      4220 non-null   float64
#  10  MeanTimeGap       4220 non-null   float64
#  11  Nsessions         4216 non-null   float64
#  12  DistinctProd      4220 non-null   int64
# dtypes: float64(10), int64(3)
# memory usage: 461.6 KB

# %%
Customer_10
# Out:
#       Customer ID  MeanProdSale  TotalSale  TotalProd  MeanSpentSession  \
# 0         14590.0      4.068153    2592.13        783        117.824091
# 1         13287.0      3.054151     583.77        319         97.295000
# 2         16550.0      2.694926    6376.10       3888        335.584211
# 3         14680.0      2.829765   29393.66      13842        459.275938
# 4         17372.0      3.026513    2830.28       1157        134.775238
# ...           ...           ...        ...        ...               ...
# 4215      16270.0      3.222778    1141.24        688       1141.240000
# 4216      12515.0      4.900000     278.70        128        278.700000
# 4217      12383.0      0.945278     555.72        751        555.720000
# 4218      13817.0      1.900000     110.70         62        110.700000
# 4219      12585.0      2.589531    1154.85        866       1154.850000
#
#       MeanProdSession  TotalSpentRet  TotalProdRet  MinProdSpent  \
# 0           35.590909        2656.96            13          0.85
# 1           53.166667         781.59           110          7.50
# 2          204.631579        6614.85            49          1.05
# 3          216.281250       30213.83           345          0.84
# 4           55.095238        2882.41            49          0.21
# ...               ...            ...           ...           ...
# 4215       688.000000        1141.24             0         10.08
# 4216       128.000000         278.70             0          9.00
# 4217       751.000000         555.72             0          5.04
# 4218        62.000000         110.70             0         10.20
# 4219       866.000000        1154.85             0          6.96
#
#       MaxProdSpent  MeanTimeGap  Nsessions  DistinctProd
# 0            100.8    14.619048       17.0           104
# 1             25.5    21.000000        3.0            46
# 2             90.0    15.705882       12.0           194
# 3            306.0     5.606557       41.0           181
# 4             76.5    15.850000       18.0           298
# ...            ...          ...        ...           ...
# 4215         102.0     0.000000        1.0            54
# 4216          25.5     0.000000        1.0            15
# 4217          47.4     0.000000        1.0            36
# 4218          19.5     0.000000        1.0             8
# 4219          91.8     0.000000        1.0            64
#
# [4220 rows x 13 columns]

# %%
Customer_10.loc[Customer_10['MeanProdSale'].isnull(),'MeanProdSale'] = 0

# %%
Customer_10.loc[Customer_10['Nsessions'].isnull(),'Nsessions'] = 0

# %%
Customer_10.to_csv(r'C:\Users\Stefano\Desktop\Data-Mining-Project\dataset\new_Customer_2010.csv', index = False, header=True)

# %%
df = pd.read_csv('../dataset/customer/new_Customer_2010_old.csv', sep=',', index_col=0)

# %%
df_10=df[df['TotalSale']>0]

# %%
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
sn.heatmap(df_10.corr(), annot=True)
plt.show()

# %%
corr_threshold = 0.8
print("Att. A\tAtt. B\tCorr(A,B)")
for i in range(0, len(df_10.columns)):
    for j in range(i+1, len(df_10.columns)):
        corr = df_10[df_10.columns[i]].corr(df_10[df_10.columns[j]])
        if  corr > corr_threshold:
            print(df_10.columns[i] + "\t" + df_10.columns[j] + "\t" + '{:.4f}'.format(corr))
# Out:
# Att. A	Att. B	Corr(A,B)
# TotalSale	TotalSpentRet	0.9991

# %%
corr_columns = ['TotalSpentRet']
df_10.drop(corr_columns, axis=1, inplace=True)
# Out:
# <ipython-input-9-206a3834c059>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10.drop(corr_columns, axis=1, inplace=True)

# %%
df_10.to_csv(r'C:\Users\Stefano\Desktop\Data-Mining-Project\dataset\customer\new_Customer_2010.csv', header=True)
