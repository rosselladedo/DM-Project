# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import math
from tqdm.notebook import tqdm

# %%
df = pd.read_csv('dataset/Basket.csv', sep=',')
df
# Out:
#                 Country  Customer ID                          Description  \
# 0        United Kingdom      13085.0  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1        United Kingdom      13085.0                   PINK CHERRY LIGHTS
# 2        United Kingdom      13085.0                  WHITE CHERRY LIGHTS
# 3        United Kingdom      13085.0         RECORD FRAME 7" SINGLE SIZE
# 4        United Kingdom      13085.0       STRAWBERRY CERAMIC TRINKET BOX
# ...                 ...          ...                                  ...
# 1067366          France      12680.0         CHILDREN'S APRON DOLLY GIRL
# 1067367          France      12680.0        CHILDRENS CUTLERY DOLLY GIRL
# 1067368          France      12680.0      CHILDRENS CUTLERY CIRCUS PARADE
# 1067369          France      12680.0        BAKING SET 9 PIECE RETROSPOT
# 1067370          France      12680.0                              POSTAGE
#
#         Invoice       InvoiceDate Price  Quantity StockCode
# 0        489434  01/12/2009 07:45  6,95        12     85048
# 1        489434  01/12/2009 07:45  6,75        12    79323P
# 2        489434  01/12/2009 07:45  6,75        12    79323W
# 3        489434  01/12/2009 07:45   2,1        48     22041
# 4        489434  01/12/2009 07:45  1,25        24     21232
# ...         ...               ...   ...       ...       ...
# 1067366  581587  09/12/2011 12:50   2,1         6     22899
# 1067367  581587  09/12/2011 12:50  4,15         4     23254
# 1067368  581587  09/12/2011 12:50  4,15         4     23255
# 1067369  581587  09/12/2011 12:50  4,95         3     22138
# 1067370  581587  09/12/2011 12:50    18         1      POST
#
# [1067371 rows x 8 columns]

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']) # converting 'InvoiceDate' to datetime
df['Price'] = df['Price'].str.replace(',','.')
df['Price'] =df['Price'].astype(float)

# %%
pd.options.display.float_format = '{:.2f}'.format
df.describe() # this function provides a summary of statistical informations
# Out:
#        Customer ID      Price   Quantity
# count    824364.00 1067371.00 1067371.00
# mean      15324.64       4.65       9.94
# std        1697.46     123.55     172.71
# min       12346.00  -53594.36  -80995.00
# 25%       13975.00       1.25       1.00
# 50%       15255.00       2.10       3.00
# 75%       16797.00       4.15      10.00
# max       18287.00   38970.00   80995.00

# %%
df.isnull().any()
# Out:
# Country        False
# Customer ID     True
# Description     True
# Invoice        False
# InvoiceDate    False
# Price          False
# Quantity       False
# StockCode      False
# dtype: bool

# %%
df[df['Customer ID'].isnull()]
# Out:
#                 Country  Customer ID                     Description Invoice  \
# 263      United Kingdom          NaN                    85123a mixed  489464
# 283      United Kingdom          NaN                           short  489463
# 284      United Kingdom          NaN                     21733 mixed  489467
# 470      United Kingdom          NaN                             NaN  489521
# 577      United Kingdom          NaN       BLUE PULL BACK RACING CAR  489525
# ...                 ...          ...                             ...     ...
# 1066997  United Kingdom          NaN         JUMBO BAG RED RETROSPOT  581498
# 1066998  United Kingdom          NaN  JUMBO  BAG BAROQUE BLACK WHITE  581498
# 1066999  United Kingdom          NaN   LADIES & GENTLEMEN METAL SIGN  581498
# 1067000  United Kingdom          NaN               S/4 CACTI CANDLES  581498
# 1067001  United Kingdom          NaN                  DOTCOM POSTAGE  581498
#
#                 InvoiceDate   Price  Quantity StockCode
# 263     2009-01-12 10:52:00    0.00       -96     21733
# 283     2009-01-12 10:52:00    0.00      -240     71477
# 284     2009-01-12 10:53:00    0.00      -192    85123A
# 470     2009-01-12 11:44:00    0.00       -50     21646
# 577     2009-01-12 11:49:00    0.55         1    85226C
# ...                     ...     ...       ...       ...
# 1066997 2011-09-12 10:26:00    4.13         5    85099B
# 1066998 2011-09-12 10:26:00    4.13         4    85099C
# 1066999 2011-09-12 10:26:00    4.96         1     85150
# 1067000 2011-09-12 10:26:00   10.79         1     85174
# 1067001 2011-09-12 10:26:00 1714.17         1       DOT
#
# [243007 rows x 8 columns]

# %%
df=df[df['Customer ID'].isnull()==False]

# %%
df.dtypes
# Out:
# Country                object
# Customer ID           float64
# Description            object
# Invoice                object
# InvoiceDate    datetime64[ns]
# Price                 float64
# Quantity                int64
# StockCode              object
# dtype: object

# %%
df.boxplot(column=['Quantity'])
# Out:
# <AxesSubplot:>

# %%
df[(df.Invoice.str.contains('C'))]
# Out:
#                 Country  Customer ID                       Description  \
# 178           Australia     16321.00          PAPER BUNTING WHITE LACE
# 179           Australia     16321.00      CREAM FELT EASTER EGG BASKET
# 180           Australia     16321.00     POTTING SHED SOW 'N' GROW SET
# 181           Australia     16321.00                POTTING SHED TWINE
# 182           Australia     16321.00        PAPER CHAIN KIT RETRO SPOT
# ...                 ...          ...                               ...
# 1065910  United Kingdom     14397.00   ZINC T-LIGHT HOLDER STARS SMALL
# 1067002  United Kingdom     15498.00                            Manual
# 1067176  United Kingdom     15311.00        VICTORIAN SEWING BOX LARGE
# 1067177  United Kingdom     17315.00  HANGING HEART JAR T-LIGHT HOLDER
# 1067178  United Kingdom     17315.00     36 PENCILS TUBE RED RETROSPOT
#
#          Invoice         InvoiceDate  Price  Quantity StockCode
# 178      C489449 2009-01-12 10:33:00   2.95       -12     22087
# 179      C489449 2009-01-12 10:33:00   1.65        -6    85206A
# 180      C489449 2009-01-12 10:33:00   4.25        -4     21895
# 181      C489449 2009-01-12 10:33:00   2.10        -6     21896
# 182      C489449 2009-01-12 10:33:00   2.95       -12     22083
# ...          ...                 ...    ...       ...       ...
# 1065910  C581490 2011-09-12 09:57:00   0.83       -11     23144
# 1067002  C581499 2011-09-12 10:28:00 224.69        -1         M
# 1067176  C581568 2011-09-12 11:57:00  10.95        -5     21258
# 1067177  C581569 2011-09-12 11:58:00   1.25        -1     84978
# 1067178  C581569 2011-09-12 11:58:00   1.25        -5     20979
#
# [18744 rows x 8 columns]

# %%
df[(df.StockCode.str.contains('A'))]
# Out:
#                 Country  Customer ID                         Description  \
# 61       United Kingdom     18102.00  CHARLIE+LOLA RED HOT WATER BOTTLE
# 63       United Kingdom     18102.00  CHARLIE+LOLA PINK HOT WATER BOTTLE
# 65       United Kingdom     18102.00     TOMATO CHARLIE+LOLA COASTER SET
# 67       United Kingdom     18102.00        CHARLIE + LOLA BISCUITS TINS
# 69       United Kingdom     18102.00  CHARLIE & LOLA WASTEPAPER BIN BLUE
# ...                 ...          ...                                 ...
# 1067059  United Kingdom     17754.00  CHARLIE+LOLA RED HOT WATER BOTTLE
# 1067100  United Kingdom     14446.00  CREAM HANGING HEART T-LIGHT HOLDER
# 1067133  United Kingdom     14446.00     TOMATO CHARLIE+LOLA COASTER SET
# 1067302  United Kingdom     12748.00           75 GREEN PETIT FOUR CASES
# 1067308  United Kingdom     12748.00       TRADITIONAL CHRISTMAS RIBBONS
#
#         Invoice         InvoiceDate  Price  Quantity StockCode
# 61       489438 2009-01-12 09:24:00   3.00        56    84031A
# 63       489438 2009-01-12 09:24:00   1.90        60    84032A
# 65       489438 2009-01-12 09:24:00   2.15        56    84519A
# 67       489438 2009-01-12 09:24:00   6.38        60    85132A
# 69       489438 2009-01-12 09:24:00   2.40        60    85183A
# ...         ...                 ...    ...       ...       ...
# 1067059  581514 2011-09-12 11:20:00   1.25        10    84031A
# 1067100  581538 2011-09-12 11:34:00   2.95         1    85123A
# 1067133  581538 2011-09-12 11:34:00   1.25         1    84519A
# 1067302  581580 2011-09-12 12:20:00   0.42         2    84993A
# 1067308  581580 2011-09-12 12:20:00   1.25         1    85049A
#
# [22515 rows x 8 columns]

# %%
df[(df.StockCode.str.contains('D'))]
# Out:
#                 Country  Customer ID                        Description  \
# 197      United Kingdom     17592.00           PINK SWEETHEART BRACELET
# 204      United Kingdom     17592.00     CRYSTAL PAIR HEART HAIR SLIDES
# 208      United Kingdom     17592.00   DIAMANTE BOW BROOCH BLACK COLOUR
# 244      United Kingdom     17592.00           PINK SWEETHEART BRACELET
# 258      United Kingdom     17592.00     CRYSTAL PAIR HEART HAIR SLIDES
# ...                 ...          ...                                ...
# 1065577  United Kingdom     13077.00          4 SKY BLUE DINNER CANDLES
# 1065827  United Kingdom     17364.00    CHILDRENS CUTLERY POLKADOT PINK
# 1067066  United Kingdom     17754.00  SET OF 3 BIRD LIGHT PINK FEATHER
# 1067147  United Kingdom     14446.00           RETRO PLASTIC DAISY TRAY
# 1067237         Germany     12713.00    CHILDRENS CUTLERY POLKADOT PINK
#
#          Invoice         InvoiceDate  Price  Quantity StockCode
# 197      C489459 2009-01-12 10:44:00   4.25        -3    90200D
# 204      C489459 2009-01-12 10:44:00   3.75        -3    90003D
# 208      C489459 2009-01-12 10:44:00   6.35        -2    90082D
# 244       489462 2009-01-12 10:49:00   4.25         3    90200D
# 258       489462 2009-01-12 10:49:00   3.75         3    90003D
# ...          ...                 ...    ...       ...       ...
# 1065577   581467 2011-08-12 19:24:00   1.25         3    72801D
# 1065827   581478 2011-09-12 08:59:00   4.15         4    84997D
# 1067066   581514 2011-09-12 11:20:00   0.39        12    35471D
# 1067147   581538 2011-09-12 11:34:00   0.85         1    79191D
# 1067237   581578 2011-09-12 12:16:00   4.15         8    84997D
#
# [6776 rows x 8 columns]

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\anaconda3\lib\site-packages (4.50.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
all_paired = True
count_pairs = count_not_paired = 0
for index, row in tqdm(df[df['Quantity'] < 0].iterrows(), total=len(df[df['Quantity'] < 0]), desc='Iterating over negative Qta rows'):
    df_aux = df[df['Customer ID'] == row['Customer ID']]
    df_aux = df_aux[df_aux['StockCode'] == row['StockCode']]
    df_aux = df_aux[df_aux['Quantity'] > 0]
    if len(df_aux) > 0:
        count_pairs += 1
    else:
        all_paired = False
        count_not_paired += 1

del df_aux

print("All negative entries have a corresponding positive one: ", all_paired)
print("The negative entries which are not matched are: ", count_not_paired)
print("The negative entries which are matched are: ", count_pairs)
assert(len(df[df['Quantity'] < 0]) == count_not_paired + count_pairs)
# Out:
# HBox(children=(HTML(value='Iterating over negative Qta rows'), FloatProgress(value=0.0, max=18744.0), HTML(val…
# All negative entries have a corresponding positive one:  False
# The negative entries which are not matched are:  1484
# The negative entries which are matched are:  17260

# %%
#Initialize variables to analyze correctness of negative Qta rows
# Dictionaries indexed by tuple (CustomerID, ProdID, Sale), value is Qta (or (Qta, list(indexes)) )
pos_quant_tot = {}
neg_quant_tot = {}

for index, row in tqdm(df.iterrows(), total=len(df), desc="Iterating over dataset"):
    if row['Quantity'] > 0:
        if (row['Customer ID'], row['StockCode'], row['Price']) not in pos_quant_tot.keys():
            pos_quant_tot[(row['Customer ID'], row['StockCode'], row['Price'])] = row['Quantity']
        else:
            pos_quant_tot[(row['Customer ID'], row['StockCode'], row['Price'])] += row['Quantity']

    elif row['StockCode'] != 'D':  # exclude 'Discount' rows from those dictionaries --> they won't be dropped from df
        if (row['Customer ID'], row['StockCode'], row['Price']) not in neg_quant_tot.keys():
            l = [index]
            neg_quant_tot[(row['Customer ID'], row['StockCode'], row['Price'])] = (-1*row['Quantity'], l)
        else:
            prev = neg_quant_tot[(row['Customer ID'], row['StockCode'], row['Price'])]
            prev[1].append(index)
            neg_quant_tot[(row['Customer ID'], row['StockCode'], row['Price'])] = (prev[0]-row['Quantity'], prev[1])

positive_elements = set(pos_quant_tot.keys())
negative_elements = set(neg_quant_tot.keys())
# Out:
# HBox(children=(HTML(value='Iterating over dataset'), FloatProgress(value=0.0, max=824364.0), HTML(value='')))

# %%
# drop negative Qta rows that are not matched with positive ones
not_valid = negative_elements - (positive_elements & negative_elements)
indexes_todelete = []
for key in not_valid:
    for x in neg_quant_tot[key][1]:
        indexes_todelete.append(x)
df.drop(indexes_todelete, inplace=True)
# Out:
# <ipython-input-22-cc4b76f22831>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(indexes_todelete, inplace=True)

# %%
# drop negative Qta rows that are invalid ( neg_qta > pos_qta )
indexes_todelete = []
for key in positive_elements & negative_elements:
    if pos_quant_tot[key] < neg_quant_tot[key][0]:
            for x in neg_quant_tot[key][1]:
                indexes_todelete.append(x)
df.drop(indexes_todelete, inplace=True)
# Out:
# <ipython-input-23-bf460c0aecaf>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(indexes_todelete, inplace=True)

# %%
df
# Out:
#                 Country  Customer ID                          Description  \
# 0        United Kingdom     13085.00  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1        United Kingdom     13085.00                   PINK CHERRY LIGHTS
# 2        United Kingdom     13085.00                  WHITE CHERRY LIGHTS
# 3        United Kingdom     13085.00         RECORD FRAME 7" SINGLE SIZE
# 4        United Kingdom     13085.00       STRAWBERRY CERAMIC TRINKET BOX
# ...                 ...          ...                                  ...
# 1067366          France     12680.00         CHILDREN'S APRON DOLLY GIRL
# 1067367          France     12680.00        CHILDRENS CUTLERY DOLLY GIRL
# 1067368          France     12680.00      CHILDRENS CUTLERY CIRCUS PARADE
# 1067369          France     12680.00        BAKING SET 9 PIECE RETROSPOT
# 1067370          France     12680.00                              POSTAGE
#
#         Invoice         InvoiceDate  Price  Quantity StockCode
# 0        489434 2009-01-12 07:45:00   6.95        12     85048
# 1        489434 2009-01-12 07:45:00   6.75        12    79323P
# 2        489434 2009-01-12 07:45:00   6.75        12    79323W
# 3        489434 2009-01-12 07:45:00   2.10        48     22041
# 4        489434 2009-01-12 07:45:00   1.25        24     21232
# ...         ...                 ...    ...       ...       ...
# 1067366  581587 2011-09-12 12:50:00   2.10         6     22899
# 1067367  581587 2011-09-12 12:50:00   4.15         4     23254
# 1067368  581587 2011-09-12 12:50:00   4.15         4     23255
# 1067369  581587 2011-09-12 12:50:00   4.95         3     22138
# 1067370  581587 2011-09-12 12:50:00  18.00         1      POST
#
# [821797 rows x 8 columns]

# %%
df[df['StockCode']=='BANK CHARGES']
# Out:
#                 Country  Customer ID    Description  Invoice  \
# 18466    United Kingdom     16805.00   Bank Charges   490948
# 94431    United Kingdom     16928.00   Bank Charges   498269
# 148098   United Kingdom     17539.00   Bank Charges   503497
# 149063   United Kingdom     17539.00   Bank Charges  C503571
# 153573   United Kingdom     12843.00   Bank Charges   503960
# 167424   United Kingdom     17448.00   Bank Charges   505204
# 206572   United Kingdom     17448.00   Bank Charges   509375
# 210149   United Kingdom     17448.00   Bank Charges   509669
# 231102   United Kingdom     17032.00   Bank Charges   511774
# 240612   United Kingdom     14085.00   Bank Charges   512658
# 272460   United Kingdom     14606.00   Bank Charges   515845
# 272462   United Kingdom     17448.00   Bank Charges   515855
# 290258   United Kingdom     14606.00   Bank Charges   517648
# 290308   United Kingdom     17448.00   Bank Charges   517652
# 300726   United Kingdom     14606.00   Bank Charges   518666
# 300727   United Kingdom     14606.00   Bank Charges   518667
# 331934             EIRE     14911.00   Bank Charges   521809
# 332015   United Kingdom     16271.00   Bank Charges   521812
# 343556   United Kingdom     17032.00   Bank Charges  C522928
# 455268   United Kingdom     13174.00   Bank Charges   532637
# 493162   United Kingdom     16928.00   Bank Charges   535474
# 507344   United Kingdom     15823.00   Bank Charges   536779
# 529867   United Kingdom     15823.00   Bank Charges   536779
# 587969   United Kingdom     15939.00   Bank Charges   541505
# 678427   United Kingdom     14606.00   Bank Charges   549717
# 700736   United Kingdom     16714.00   Bank Charges   551945
# 853382   United Kingdom     16904.00   Bank Charges   565735
# 887201   United Kingdom     13405.00   Bank Charges   568375
# 887202   United Kingdom     13405.00   Bank Charges   568375
# 933079   United Kingdom     13263.00   Bank Charges   571900
# 956824   United Kingdom     14704.00   Bank Charges   573586
# 966206   United Kingdom     13651.00   Bank Charges   574546
# 1031818  United Kingdom     14704.00   Bank Charges   579137
# 1059469  United Kingdom     16271.00   Bank Charges   581127
#
#                 InvoiceDate  Price  Quantity     StockCode
# 18466   2009-08-12 14:29:00  15.00         1  BANK CHARGES
# 94431   2010-02-17 15:03:00  15.00         1  BANK CHARGES
# 148098  2010-01-04 12:07:00  15.00         1  BANK CHARGES
# 149063  2010-01-04 15:45:00  15.00        -1  BANK CHARGES
# 153573  2010-08-04 16:50:00  15.00         1  BANK CHARGES
# 167424  2010-04-20 16:24:00  15.00         1  BANK CHARGES
# 206572  2010-05-21 14:40:00  15.00         1  BANK CHARGES
# 210149  2010-05-25 12:03:00  15.00         1  BANK CHARGES
# 231102  2010-10-06 12:16:00  15.00         1  BANK CHARGES
# 240612  2010-06-17 11:24:00  15.00         1  BANK CHARGES
# 272460  2010-07-15 11:21:00  15.00         1  BANK CHARGES
# 272462  2010-07-15 11:24:00  15.00         1  BANK CHARGES
# 290258  2010-07-30 13:52:00  15.00         1  BANK CHARGES
# 290308  2010-07-30 14:07:00  15.00         1  BANK CHARGES
# 300726  2010-10-08 14:45:00  15.00         1  BANK CHARGES
# 300727  2010-10-08 14:47:00  15.00         1  BANK CHARGES
# 331934  2010-08-09 14:33:00  15.00         1  BANK CHARGES
# 332015  2010-08-09 15:00:00  15.00         1  BANK CHARGES
# 343556  2010-09-17 14:37:00  15.00        -1  BANK CHARGES
# 455268  2010-12-11 16:18:00  15.00         1  BANK CHARGES
# 493162  2010-11-26 13:56:00  15.00         1  BANK CHARGES
# 507344  2010-02-12 15:08:00  15.00         1  BANK CHARGES
# 529867  2010-02-12 15:08:00  15.00         1  BANK CHARGES
# 587969  2011-01-18 15:58:00  15.00         1  BANK CHARGES
# 678427  2011-11-04 14:56:00  15.00         1  BANK CHARGES
# 700736  2011-05-05 11:09:00  15.00         1  BANK CHARGES
# 853382  2011-06-09 12:25:00  15.00         1  BANK CHARGES
# 887201  2011-09-26 17:01:00  15.00         1  BANK CHARGES
# 887202  2011-09-26 17:01:00   0.00         1  BANK CHARGES
# 933079  2011-10-19 14:26:00  15.00         1  BANK CHARGES
# 956824  2011-10-31 14:48:00  15.00         1  BANK CHARGES
# 966206  2011-04-11 14:59:00  15.00         1  BANK CHARGES
# 1031818 2011-11-28 12:51:00  15.00         1  BANK CHARGES
# 1059469 2011-07-12 12:45:00  15.00         1  BANK CHARGES

# %%
df=df[df['StockCode']!='BANK CHARGES']

# %%
df
# Out:
#                 Country  Customer ID                          Description  \
# 0        United Kingdom     13085.00  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1        United Kingdom     13085.00                   PINK CHERRY LIGHTS
# 2        United Kingdom     13085.00                  WHITE CHERRY LIGHTS
# 3        United Kingdom     13085.00         RECORD FRAME 7" SINGLE SIZE
# 4        United Kingdom     13085.00       STRAWBERRY CERAMIC TRINKET BOX
# ...                 ...          ...                                  ...
# 1067366          France     12680.00         CHILDREN'S APRON DOLLY GIRL
# 1067367          France     12680.00        CHILDRENS CUTLERY DOLLY GIRL
# 1067368          France     12680.00      CHILDRENS CUTLERY CIRCUS PARADE
# 1067369          France     12680.00        BAKING SET 9 PIECE RETROSPOT
# 1067370          France     12680.00                              POSTAGE
#
#         Invoice         InvoiceDate  Price  Quantity StockCode
# 0        489434 2009-01-12 07:45:00   6.95        12     85048
# 1        489434 2009-01-12 07:45:00   6.75        12    79323P
# 2        489434 2009-01-12 07:45:00   6.75        12    79323W
# 3        489434 2009-01-12 07:45:00   2.10        48     22041
# 4        489434 2009-01-12 07:45:00   1.25        24     21232
# ...         ...                 ...    ...       ...       ...
# 1067366  581587 2011-09-12 12:50:00   2.10         6     22899
# 1067367  581587 2011-09-12 12:50:00   4.15         4     23254
# 1067368  581587 2011-09-12 12:50:00   4.15         4     23255
# 1067369  581587 2011-09-12 12:50:00   4.95         3     22138
# 1067370  581587 2011-09-12 12:50:00  18.00         1      POST
#
# [821763 rows x 8 columns]

# %%
df[df['StockCode']=='POST']
# Out:
#          Country  Customer ID Description Invoice         InvoiceDate  Price  \
# 89        France     12682.00     POSTAGE  489439 2009-01-12 09:28:00  18.00
# 126          USA     12636.00     POSTAGE  489444 2009-01-12 09:55:00 141.00
# 173      Belgium     12362.00     POSTAGE  489447 2009-01-12 10:10:00 130.00
# 625      Germany     12533.00     POSTAGE  489526 2009-01-12 11:50:00  18.00
# 1244      France     12490.00     POSTAGE  489557 2009-01-12 12:52:00  18.00
# ...          ...          ...         ...     ...                 ...    ...
# 1066677  Germany     12518.00     POSTAGE  581494 2011-09-12 10:13:00  18.00
# 1067191  Germany     12662.00     POSTAGE  581570 2011-09-12 11:59:00  18.00
# 1067228  Germany     12526.00     POSTAGE  581574 2011-09-12 12:09:00  18.00
# 1067229  Germany     12713.00     POSTAGE  581578 2011-09-12 12:16:00  18.00
# 1067370   France     12680.00     POSTAGE  581587 2011-09-12 12:50:00  18.00
#
#          Quantity StockCode
# 89              3      POST
# 126             1      POST
# 173             1      POST
# 625             6      POST
# 1244            4      POST
# ...           ...       ...
# 1066677         2      POST
# 1067191         1      POST
# 1067228         2      POST
# 1067229         3      POST
# 1067370         1      POST
#
# [1900 rows x 8 columns]

# %%
df=df[df['StockCode']!='POST']

# %%
df
# Out:
#                 Country  Customer ID                          Description  \
# 0        United Kingdom     13085.00  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1        United Kingdom     13085.00                   PINK CHERRY LIGHTS
# 2        United Kingdom     13085.00                  WHITE CHERRY LIGHTS
# 3        United Kingdom     13085.00         RECORD FRAME 7" SINGLE SIZE
# 4        United Kingdom     13085.00       STRAWBERRY CERAMIC TRINKET BOX
# ...                 ...          ...                                  ...
# 1067365          France     12680.00          PACK OF 20 SPACEBOY NAPKINS
# 1067366          France     12680.00         CHILDREN'S APRON DOLLY GIRL
# 1067367          France     12680.00        CHILDRENS CUTLERY DOLLY GIRL
# 1067368          France     12680.00      CHILDRENS CUTLERY CIRCUS PARADE
# 1067369          France     12680.00        BAKING SET 9 PIECE RETROSPOT
#
#         Invoice         InvoiceDate  Price  Quantity StockCode
# 0        489434 2009-01-12 07:45:00   6.95        12     85048
# 1        489434 2009-01-12 07:45:00   6.75        12    79323P
# 2        489434 2009-01-12 07:45:00   6.75        12    79323W
# 3        489434 2009-01-12 07:45:00   2.10        48     22041
# 4        489434 2009-01-12 07:45:00   1.25        24     21232
# ...         ...                 ...    ...       ...       ...
# 1067365  581587 2011-09-12 12:50:00   0.85        12     22613
# 1067366  581587 2011-09-12 12:50:00   2.10         6     22899
# 1067367  581587 2011-09-12 12:50:00   4.15         4     23254
# 1067368  581587 2011-09-12 12:50:00   4.15         4     23255
# 1067369  581587 2011-09-12 12:50:00   4.95         3     22138
#
# [819863 rows x 8 columns]

# %%
df[df['StockCode']=='DOT']
# Out:
#                 Country  Customer ID     Description Invoice  \
# 842968   United Kingdom     14096.00  DOTCOM POSTAGE  564764
# 849463   United Kingdom     14096.00  DOTCOM POSTAGE  565383
# 859217   United Kingdom     14096.00  DOTCOM POSTAGE  566217
# 864291   United Kingdom     14096.00  DOTCOM POSTAGE  566566
# 876061   United Kingdom     14096.00  DOTCOM POSTAGE  567656
# 887045   United Kingdom     14096.00  DOTCOM POSTAGE  568346
# 898227   United Kingdom     14096.00  DOTCOM POSTAGE  569246
# 915445   United Kingdom     14096.00  DOTCOM POSTAGE  570488
# 927227   United Kingdom     14096.00  DOTCOM POSTAGE  571441
# 941925   United Kingdom     14096.00  DOTCOM POSTAGE  572552
# 955049   United Kingdom     14096.00  DOTCOM POSTAGE  573576
# 980722   United Kingdom     14096.00  DOTCOM POSTAGE  575607
# 992898   United Kingdom     14096.00  DOTCOM POSTAGE  576339
# 1020188  United Kingdom     14096.00  DOTCOM POSTAGE  578270
# 1033920  United Kingdom     14096.00  DOTCOM POSTAGE  579196
# 1053544  United Kingdom     14096.00  DOTCOM POSTAGE  580727
#
#                 InvoiceDate   Price  Quantity StockCode
# 842968  2011-08-30 10:49:00   11.17         1       DOT
# 849463  2011-02-09 15:45:00   16.46         1       DOT
# 859217  2011-09-09 15:17:00   13.16         1       DOT
# 864291  2011-09-13 12:32:00   85.58         1       DOT
# 876061  2011-09-21 14:40:00  878.55         1       DOT
# 887045  2011-09-26 15:28:00  688.08         1       DOT
# 898227  2011-03-10 09:57:00  490.25         1       DOT
# 915445  2011-10-10 17:12:00  635.01         1       DOT
# 927227  2011-10-17 13:31:00  743.62         1       DOT
# 941925  2011-10-24 17:07:00  638.30         1       DOT
# 955049  2011-10-31 14:09:00  901.58         1       DOT
# 980722  2011-10-11 12:37:00  908.16         1       DOT
# 992898  2011-11-14 15:27:00 1500.36         1       DOT
# 1020188 2011-11-23 13:39:00 1270.06         1       DOT
# 1033920 2011-11-28 15:54:00 1526.76         1       DOT
# 1053544 2011-05-12 17:17:00 1599.26         1       DOT

# %%
df=df[df['StockCode']!='DOT']

# %%
df[df['StockCode']=='M']
# Out:
#                 Country  Customer ID Description Invoice         InvoiceDate  \
# 11310    United Kingdom     12970.00      Manual  490300 2009-04-12 14:19:00
# 11311    United Kingdom     12970.00      Manual  490300 2009-04-12 14:19:00
# 16107    United Kingdom     17231.00      Manual  490727 2009-07-12 16:38:00
# 17386    United Kingdom     14295.00      Manual  490760 2009-08-12 09:49:00
# 17887    United Kingdom     16210.00      Manual  490881 2009-08-12 12:58:00
# ...                 ...          ...         ...     ...                 ...
# 1051476  United Kingdom     17857.00      Manual  580645 2011-05-12 13:11:00
# 1051479  United Kingdom     17857.00      Manual  580646 2011-05-12 13:13:00
# 1056337  United Kingdom     15907.00      Manual  580884 2011-06-12 12:21:00
# 1056893  United Kingdom     17841.00      Manual  580956 2011-06-12 14:23:00
# 1063782  United Kingdom     13521.00      Manual  581405 2011-08-12 13:50:00
#
#          Price  Quantity StockCode
# 11310     0.85         1         M
# 11311     0.21         1         M
# 16107     0.00         1         M
# 17386    10.00         1         M
# 17887    10.00         1         M
# ...        ...       ...       ...
# 1051476 219.50         1         M
# 1051479   0.25       800         M
# 1056337   0.85         1         M
# 1056893   1.25         4         M
# 1063782   0.42         3         M
#
# [819 rows x 8 columns]

# %%
df=df[df['StockCode']!='M']

# %%
df
# Out:
#                 Country  Customer ID                          Description  \
# 0        United Kingdom     13085.00  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1        United Kingdom     13085.00                   PINK CHERRY LIGHTS
# 2        United Kingdom     13085.00                  WHITE CHERRY LIGHTS
# 3        United Kingdom     13085.00         RECORD FRAME 7" SINGLE SIZE
# 4        United Kingdom     13085.00       STRAWBERRY CERAMIC TRINKET BOX
# ...                 ...          ...                                  ...
# 1067365          France     12680.00          PACK OF 20 SPACEBOY NAPKINS
# 1067366          France     12680.00         CHILDREN'S APRON DOLLY GIRL
# 1067367          France     12680.00        CHILDRENS CUTLERY DOLLY GIRL
# 1067368          France     12680.00      CHILDRENS CUTLERY CIRCUS PARADE
# 1067369          France     12680.00        BAKING SET 9 PIECE RETROSPOT
#
#         Invoice         InvoiceDate  Price  Quantity StockCode
# 0        489434 2009-01-12 07:45:00   6.95        12     85048
# 1        489434 2009-01-12 07:45:00   6.75        12    79323P
# 2        489434 2009-01-12 07:45:00   6.75        12    79323W
# 3        489434 2009-01-12 07:45:00   2.10        48     22041
# 4        489434 2009-01-12 07:45:00   1.25        24     21232
# ...         ...                 ...    ...       ...       ...
# 1067365  581587 2011-09-12 12:50:00   0.85        12     22613
# 1067366  581587 2011-09-12 12:50:00   2.10         6     22899
# 1067367  581587 2011-09-12 12:50:00   4.15         4     23254
# 1067368  581587 2011-09-12 12:50:00   4.15         4     23255
# 1067369  581587 2011-09-12 12:50:00   4.95         3     22138
#
# [819028 rows x 8 columns]

# %% [markdown]
# <h2>Outliers Detection</h2>

# %%
f, axs = plt.subplots(ncols=2, figsize=(10,5))
axs[0].boxplot(df.Price)
axs[0].set_title('Boxplot of Price')
axs[1].boxplot(df.Quantity)
axs[1].set_title('Boxplot of Quantity')
plt.show()

# %%
limit = 10000
print(f"Number of rows with a value of 'Qta' > 10000: {len(df[df['Quantity'] > limit])}")
print(f"Number of rows with a value of 'Qta' < -10000: {len(df[df['Quantity'] < -limit])}")
# Out:
# Number of rows with a value of 'Qta' > 10000: 8
# Number of rows with a value of 'Qta' < -10000: 2

# %%
# print anomalous rows
print('Rows with a quantity value grater than 60000 or less than -60000:\n')
df[(df['Quantity'] > 60000) | (df['Quantity'] < -60000)]
# Out:
# Rows with a quantity value grater than 60000 or less than -60000:
#                 Country  Customer ID                     Description  Invoice  \
# 587080   United Kingdom     12346.00  MEDIUM CERAMIC TOP STORAGE JAR   541431
# 587085   United Kingdom     12346.00  MEDIUM CERAMIC TOP STORAGE JAR  C541433
# 1065882  United Kingdom     16446.00     PAPER CRAFT , LITTLE BIRDIE   581483
# 1065883  United Kingdom     16446.00     PAPER CRAFT , LITTLE BIRDIE  C581484
#
#                 InvoiceDate  Price  Quantity StockCode
# 587080  2011-01-18 10:01:00   1.04     74215     23166
# 587085  2011-01-18 10:17:00   1.04    -74215     23166
# 1065882 2011-09-12 09:15:00   2.08     80995     23843
# 1065883 2011-09-12 09:27:00   2.08    -80995     23843

# %%
df.drop(df[(df['Quantity'] < -60000) | (df['Quantity'] > 60000)].index, inplace=True)
df.boxplot(column=['Quantity'])
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#                 Country  Customer ID                          Description  \
# 0        United Kingdom     13085.00  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1        United Kingdom     13085.00                   PINK CHERRY LIGHTS
# 2        United Kingdom     13085.00                  WHITE CHERRY LIGHTS
# 3        United Kingdom     13085.00         RECORD FRAME 7" SINGLE SIZE
# 4        United Kingdom     13085.00       STRAWBERRY CERAMIC TRINKET BOX
# ...                 ...          ...                                  ...
# 1067365          France     12680.00          PACK OF 20 SPACEBOY NAPKINS
# 1067366          France     12680.00         CHILDREN'S APRON DOLLY GIRL
# 1067367          France     12680.00        CHILDRENS CUTLERY DOLLY GIRL
# 1067368          France     12680.00      CHILDRENS CUTLERY CIRCUS PARADE
# 1067369          France     12680.00        BAKING SET 9 PIECE RETROSPOT
#
#         Invoice         InvoiceDate  Price  Quantity StockCode
# 0        489434 2009-01-12 07:45:00   6.95        12     85048
# 1        489434 2009-01-12 07:45:00   6.75        12    79323P
# 2        489434 2009-01-12 07:45:00   6.75        12    79323W
# 3        489434 2009-01-12 07:45:00   2.10        48     22041
# 4        489434 2009-01-12 07:45:00   1.25        24     21232
# ...         ...                 ...    ...       ...       ...
# 1067365  581587 2011-09-12 12:50:00   0.85        12     22613
# 1067366  581587 2011-09-12 12:50:00   2.10         6     22899
# 1067367  581587 2011-09-12 12:50:00   4.15         4     23254
# 1067368  581587 2011-09-12 12:50:00   4.15         4     23255
# 1067369  581587 2011-09-12 12:50:00   4.95         3     22138
#
# [819024 rows x 8 columns]

# %%
df.to_csv(r'C:\Users\Stefano\Desktop\Data-Mining-Project\dataset\new_Basket_3.csv', index = False, header=True)

# %%
df_09 = df[pd.DatetimeIndex(df['InvoiceDate']).year == 2009.0]
df_09
# Out:
#               Country  Customer ID                          Description  \
# 0      United Kingdom     13085.00  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1      United Kingdom     13085.00                   PINK CHERRY LIGHTS
# 2      United Kingdom     13085.00                  WHITE CHERRY LIGHTS
# 3      United Kingdom     13085.00         RECORD FRAME 7" SINGLE SIZE
# 4      United Kingdom     13085.00       STRAWBERRY CERAMIC TRINKET BOX
# ...               ...          ...                                  ...
# 45219  United Kingdom     17867.00           FLORAL FOLK STATIONERY SET
# 45220  United Kingdom     17867.00       VINTAGE PAISLEY STATIONERY SET
# 45221  United Kingdom     17867.00      BOHEMIAN COLLAGE STATIONERY SET
# 45222  United Kingdom     17867.00         REX CASH+CARRY JUMBO SHOPPER
# 45227  United Kingdom     17819.00                   PICCADILLY TEA SET
#
#       Invoice         InvoiceDate  Price  Quantity StockCode
# 0      489434 2009-01-12 07:45:00   6.95        12     85048
# 1      489434 2009-01-12 07:45:00   6.75        12    79323P
# 2      489434 2009-01-12 07:45:00   6.75        12    79323W
# 3      489434 2009-01-12 07:45:00   2.10        48     22041
# 4      489434 2009-01-12 07:45:00   1.25        24     21232
# ...       ...                 ...    ...       ...       ...
# 45219  493407 2009-12-23 16:04:00   2.95         1     21993
# 45220  493407 2009-12-23 16:04:00   2.95         1     21992
# 45221  493407 2009-12-23 16:04:00   2.95         1     21991
# 45222  493407 2009-12-23 16:04:00   0.95        10     21034
# 45227  493409 2009-12-23 16:58:00  12.75        48     20747
#
# [31207 rows x 8 columns]

# %%
f, axs = plt.subplots(ncols=2, figsize=(10,5))
axs[0].boxplot(df_09.Price)
axs[0].set_title('Boxplot of Price')
axs[1].boxplot(df_09.Quantity)
axs[1].set_title('Boxplot of Quantity')
plt.show()

# %%
df_10 = df[pd.DatetimeIndex(df['InvoiceDate']).year == 2010.0]
df_10
# Out:
#                Country  Customer ID                        Description  \
# 45228   United Kingdom     12346.00            This is a test product.
# 45229   United Kingdom     14590.00            RETRO SPOTS BUTTER DISH
# 45230   United Kingdom     12346.00            This is a test product.
# 45234   United Kingdom     14590.00                     RETRO SPOT MUG
# 45235   United Kingdom     14590.00          RETRO SPOT LARGE MILK JUG
# ...                ...          ...                                ...
# 567909  United Kingdom     18116.00  SET OF 3 BUTTERFLY COOKIE CUTTERS
# 567910  United Kingdom     18116.00              HOT BATHS SOAP HOLDER
# 567911  United Kingdom     18116.00             FAIRY SOAP SOAP HOLDER
# 567912  United Kingdom     18116.00        CREAM SWEETHEART EGG HOLDER
# 567913  United Kingdom     18116.00                TEA TIME OVEN GLOVE
#
#         Invoice         InvoiceDate  Price  Quantity StockCode
# 45228    493410 2010-04-01 09:24:00   4.50         5   TEST001
# 45229   C493411 2010-04-01 09:43:00   4.25        -1     21539
# 45230    493412 2010-04-01 09:53:00   4.50         5   TEST001
# 45234    493414 2010-04-01 10:28:00   2.55        36     21844
# 45235    493414 2010-04-01 10:28:00   4.25        12     21533
# ...         ...                 ...    ...       ...       ...
# 567909   539988 2010-12-23 16:06:00   1.25         1     84380
# 567910   539988 2010-12-23 16:06:00   1.69         1    84849D
# 567911   539988 2010-12-23 16:06:00   1.69         1    84849B
# 567912   539988 2010-12-23 16:06:00   4.95         2     22854
# 567913   539988 2010-12-23 16:06:00   1.25         2    47559B
#
# [409883 rows x 8 columns]

# %%
df_11 = df[pd.DatetimeIndex(df['InvoiceDate']).year == 2011.0]
df_11
# Out:
#                 Country  Customer ID                      Description Invoice  \
# 567942   United Kingdom     13313.00          JUMBO BAG PINK POLKADOT  539993
# 567943   United Kingdom     13313.00               BLUE POLKADOT WRAP  539993
# 567944   United Kingdom     13313.00              RED RETROSPOT WRAP   539993
# 567945   United Kingdom     13313.00         RECYCLING BAG RETROSPOT   539993
# 567946   United Kingdom     13313.00        RED RETROSPOT SHOPPER BAG  539993
# ...                 ...          ...                              ...     ...
# 1067365          France     12680.00      PACK OF 20 SPACEBOY NAPKINS  581587
# 1067366          France     12680.00     CHILDREN'S APRON DOLLY GIRL   581587
# 1067367          France     12680.00    CHILDRENS CUTLERY DOLLY GIRL   581587
# 1067368          France     12680.00  CHILDRENS CUTLERY CIRCUS PARADE  581587
# 1067369          France     12680.00    BAKING SET 9 PIECE RETROSPOT   581587
#
#                 InvoiceDate  Price  Quantity StockCode
# 567942  2011-04-01 10:00:00   1.95        10     22386
# 567943  2011-04-01 10:00:00   0.42        25     21499
# 567944  2011-04-01 10:00:00   0.42        25     21498
# 567945  2011-04-01 10:00:00   2.10         5     22379
# 567946  2011-04-01 10:00:00   1.25        10     20718
# ...                     ...    ...       ...       ...
# 1067365 2011-09-12 12:50:00   0.85        12     22613
# 1067366 2011-09-12 12:50:00   2.10         6     22899
# 1067367 2011-09-12 12:50:00   4.15         4     23254
# 1067368 2011-09-12 12:50:00   4.15         4     23255
# 1067369 2011-09-12 12:50:00   4.95         3     22138
#
# [377934 rows x 8 columns]

# %%
df_09.to_csv(r'C:\Users\Stefano\Desktop\Data-Mining-Project\dataset\new_Basket_3_2009.csv', index = False, header=True)
df_10.to_csv(r'C:\Users\Stefano\Desktop\Data-Mining-Project\dataset\new_Basket_3_2010.csv', index = False, header=True)
df_11.to_csv(r'C:\Users\Stefano\Desktop\Data-Mining-Project\dataset\new_Basket_3_2011.csv', index = False, header=True)
