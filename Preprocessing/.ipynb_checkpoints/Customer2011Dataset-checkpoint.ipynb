# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import math
from tqdm.notebook import tqdm

# %%
df = pd.read_csv('../dataset/new_Basket_3_2011.csv', sep=',')
df
# Out:
#                Country  Customer ID                      Description Invoice  \
# 0       United Kingdom      13313.0          JUMBO BAG PINK POLKADOT  539993
# 1       United Kingdom      13313.0               BLUE POLKADOT WRAP  539993
# 2       United Kingdom      13313.0              RED RETROSPOT WRAP   539993
# 3       United Kingdom      13313.0         RECYCLING BAG RETROSPOT   539993
# 4       United Kingdom      13313.0        RED RETROSPOT SHOPPER BAG  539993
# ...                ...          ...                              ...     ...
# 377894          France      12680.0      PACK OF 20 SPACEBOY NAPKINS  581587
# 377895          France      12680.0     CHILDREN'S APRON DOLLY GIRL   581587
# 377896          France      12680.0    CHILDRENS CUTLERY DOLLY GIRL   581587
# 377897          France      12680.0  CHILDRENS CUTLERY CIRCUS PARADE  581587
# 377898          France      12680.0    BAKING SET 9 PIECE RETROSPOT   581587
#
#                 InvoiceDate  Price  Quantity StockCode
# 0       2011-04-01 10:00:00   1.95        10     22386
# 1       2011-04-01 10:00:00   0.42        25     21499
# 2       2011-04-01 10:00:00   0.42        25     21498
# 3       2011-04-01 10:00:00   2.10         5     22379
# 4       2011-04-01 10:00:00   1.25        10     20718
# ...                     ...    ...       ...       ...
# 377894  2011-09-12 12:50:00   0.85        12     22613
# 377895  2011-09-12 12:50:00   2.10         6     22899
# 377896  2011-09-12 12:50:00   4.15         4     23254
# 377897  2011-09-12 12:50:00   4.15         4     23255
# 377898  2011-09-12 12:50:00   4.95         3     22138
#
# [377899 rows x 8 columns]

# %%
data = pd.core.frame.DataFrame({'Customer ID' : df['Customer ID'].unique()})
data
# Out:
#       Customer ID
# 0         13313.0
# 1         18097.0
# 2         16656.0
# 3         16875.0
# 4         13094.0
# ...           ...
# 4219      13436.0
# 4220      15520.0
# 4221      13298.0
# 4222      14569.0
# 4223      12713.0
#
# [4224 rows x 1 columns]

# %%
d_aux=df[(df['Quantity']>0) | (df['StockCode']=='D')]
#mean cost of the products in the orders in the period of observation
MeanProdSale = d_aux.groupby('Customer ID',as_index=False)['Price'].mean()
MeanProdSale.columns = ['Customer ID', 'MeanProdSale']
MeanProdSale
# Out:
#       Customer ID  MeanProdSale
# 0         12347.0      2.593510
# 1         12348.0      0.828182
# 2         12349.0      4.237500
# 3         12350.0      1.581250
# 4         12352.0      4.075455
# ...           ...           ...
# 4208      18280.0      4.765000
# 4209      18281.0      5.622857
# 4210      18282.0      5.199167
# 4211      18283.0      1.611379
# 4212      18287.0      1.493571
#
# [4213 rows x 2 columns]

# %%
#distinct products
d_aux=df[df['StockCode']!='D']
distinctProd = d_aux.groupby('Customer ID',as_index=False)['StockCode'].nunique()
distinctProd.columns = ['Customer ID', 'DistinctProd']
distinctProd
# Out:
#       Customer ID  DistinctProd
# 0         12347.0            87
# 1         12348.0             9
# 2         12349.0            72
# 3         12350.0            16
# 4         12352.0            57
# ...           ...           ...
# 4219      18280.0            10
# 4220      18281.0             7
# 4221      18282.0            12
# 4222      18283.0           262
# 4223      18287.0            59
#
# [4224 rows x 2 columns]

# %%
#number of distinct session for Customer
d_aux=df[df['Quantity']>0]
Nsessions = d_aux.groupby('Customer ID')['Invoice'].nunique().reset_index()
Nsessions.columns = ['Customer ID', 'Nsessions']
Nsessions
# Out:
#       Customer ID  Nsessions
# 0         12347.0          6
# 1         12348.0          3
# 2         12349.0          1
# 3         12350.0          1
# 4         12352.0          7
# ...           ...        ...
# 4208      18280.0          1
# 4209      18281.0          1
# 4210      18282.0          2
# 4211      18283.0         16
# 4212      18287.0          3
#
# [4213 rows x 2 columns]

# %%
#Total amount spent
total_sale = []
total_prod_returned=[]
total_sale_wret=[]
total_products=[]
min_prod_spent=[]
max_prod_spent=[]   

for customer in tqdm(df['Customer ID'].unique(), total=len(df['Customer ID'].unique()), desc="Iterating over customers"):
    df_aux = df.loc[df['Customer ID'] == customer, ['Quantity', 'Price','StockCode']]
       
    mps = []
    ts=0
    tp=0
    tpr=0
    tswr=0
    for _, row in df_aux.iterrows():
        cost = row['Quantity']*row['Price']
        tp +=row['Quantity'] if row['StockCode']!='D' else 0
        ts += cost
        
        if row['Quantity']>0 or row['StockCode']=='D':
            tswr+=cost
            if row['Quantity'] >0: # not DISCOUNT
                mps.append(cost)
        
        else:
            tpr-=row['Quantity']
    
    total_sale.append(ts)
    total_products.append(tp)
    total_sale_wret.append(tswr)
    min_prod_spent.append(min(mps,default=0))
    max_prod_spent.append(max(mps,default=0))
    total_prod_returned.append(tpr)
# Out:
# HBox(children=(HTML(value='Iterating over customers'), FloatProgress(value=0.0, max=4224.0), HTML(value='')))

# %%
sessions_per_customer = {}
data_session = df[['Invoice','Customer ID']].drop_duplicates()

for _, r in tqdm(data_session.iterrows(), total=len(data_session), desc="Iterating over orders"):
    customer = r["Customer ID"]
    session = r["Invoice"]
    df_aux = df.loc[df['Invoice'] == session, ['Quantity','Price','StockCode', 'Customer ID']]
    df_aux = df_aux.loc[df['Customer ID'] == customer, ['Quantity','Price','StockCode']]
    temp_prod = 0
    temp_sale = 0 
    
    for _, int_r in df_aux.iterrows():
        temp_prod += int_r['Quantity']
        temp_sale += int_r['Quantity']*int_r['Price']
        
    if customer not in sessions_per_customer:
        sessions_per_customer[customer] = [0,0,0]
        
    sessions_per_customer[customer][0] += temp_prod
    sessions_per_customer[customer][1] += temp_sale
    sessions_per_customer[customer][2] += 1
# Out:
# HBox(children=(HTML(value='Iterating over orders'), FloatProgress(value=0.0, max=20033.0), HTML(value='')))

# %%
mean_spent_session_wise = []     # mean amount spent (by order) per customer
mean_products_session_wise = []  # mean number of products bought per shopping session per customer

for customer in tqdm(df['Customer ID'].unique(), total=len(df['Customer ID'].unique()), desc="Iterating over customers"): 
    mean_products_session_wise.append(sessions_per_customer[customer][0] / sessions_per_customer[customer][2])
    mean_spent_session_wise.append(sessions_per_customer[customer][1] / sessions_per_customer[customer][2])
# Out:
# HBox(children=(HTML(value='Iterating over customers'), FloatProgress(value=0.0, max=4224.0), HTML(value='')))

# %%
MeanTimeGap = df.groupby(['Customer ID', 'InvoiceDate'], as_index=False)['Invoice'].count()
MeanTimeGap.columns = ['Customer ID', 'InvoiceDate','MeanTimeGap']
MeanTimeGap
# Out:
#        Customer ID          InvoiceDate  MeanTimeGap
# 0          12347.0  2011-01-26 14:30:00           29
# 1          12347.0  2011-02-08 08:48:00           22
# 2          12347.0  2011-07-04 10:43:00           24
# 3          12347.0  2011-07-12 15:52:00           11
# 4          12347.0  2011-09-06 13:01:00           18
# ...            ...                  ...          ...
# 19911      18283.0  2011-11-23 13:27:00          107
# 19912      18283.0  2011-11-30 12:59:00           52
# 19913      18287.0  2011-05-22 10:39:00           29
# 19914      18287.0  2011-10-28 09:29:00            3
# 19915      18287.0  2011-12-10 10:23:00           38
#
# [19916 rows x 3 columns]

# %%
MeanTimeGap['InvoiceDate'] = pd.to_datetime(MeanTimeGap['InvoiceDate']).dt.date
def gapTime(MeanTimeGap):
    mean_time_gap=[]
    for customer in MeanTimeGap['Customer ID'].unique():
        df_aux=MeanTimeGap[MeanTimeGap['Customer ID']==customer]
        df_aux=df_aux['InvoiceDate'].to_list()
        sum_diff_gap = 0
        for i in range(0, len(df_aux)-1):
            sum_diff_gap += (df_aux[i+1]-df_aux[i]).days

        if len(df_aux)-1 == 0:
            mean_time_gap.append(0)
        else:
            mean_time_gap.append(sum_diff_gap / (len(df_aux)-1))
    return mean_time_gap

# %%
mean_time_gap=gapTime(MeanTimeGap)
customer_time=MeanTimeGap['Customer ID'].unique()
data_tuples = list(zip(customer_time,mean_time_gap))
MeanTime=pd.DataFrame(data_tuples, columns=['Customer ID','MeanTimeGap'])
MeanTime
# Out:
#       Customer ID  MeanTimeGap
# 0         12347.0    55.600000
# 1         12348.0   121.500000
# 2         12349.0     0.000000
# 3         12350.0     0.000000
# 4         12352.0    38.285714
# ...           ...          ...
# 4219      18280.0     0.000000
# 4220      18281.0     0.000000
# 4221      18282.0   104.000000
# 4222      18283.0    20.733333
# 4223      18287.0   101.000000
#
# [4224 rows x 2 columns]

# %%
df3=pd.merge(data,MeanProdSale, how='left')

# %%
df3['TotalSale']=total_sale
df3['TotalProd']=total_products
df3['MeanSpentSession']=mean_spent_session_wise
df3['MeanProdSession']=mean_products_session_wise
df3['TotalSpentRet']=total_sale_wret
df3['TotalProdRet']=total_prod_returned
df3['MinProdSpent']=min_prod_spent
df3['MaxProdSpent']=max_prod_spent

# %%
Customer_11 =df3.merge(MeanTime, on='Customer ID').set_index('Customer ID')

# %%
Customer_11.reset_index()
# Out:
#       Customer ID  MeanProdSale  TotalSale  TotalProd  MeanSpentSession  \
# 0         13313.0      2.132308    1555.32        851        311.064000
# 1         18097.0      3.084059    2510.33       1429        418.388333
# 2         16656.0      2.254058    8139.48       8477        406.974000
# 3         16875.0      3.585268    2024.31       1046        224.923333
# 4         13094.0      1.260000    1485.18       1350         99.012000
# ...           ...           ...        ...        ...               ...
# 4219      13436.0      5.830000     196.89         76        196.890000
# 4220      15520.0      1.724444     343.50        314        343.500000
# 4221      13298.0      3.750000     360.00         96        360.000000
# 4222      14569.0      3.920000     227.39         79        227.390000
# 4223      12713.0      2.084595     794.55        505        794.550000
#
#       MeanProdSession  TotalSpentRet  TotalProdRet  MinProdSpent  \
# 0          170.200000        1555.32             0          5.04
# 1          238.166667        2515.28             1          5.04
# 2          423.850000        8197.04            21         10.08
# 3          116.222222        2095.53            23          6.96
# 4           90.000000        1703.64           174         53.10
# ...               ...            ...           ...           ...
# 4219        76.000000         196.89             0         10.20
# 4220       314.000000         343.50             0          9.48
# 4221        96.000000         360.00             0         90.00
# 4222        79.000000         227.39             0          1.65
# 4223       505.000000         794.55             0          5.04
#
#       MaxProdSpent  MeanTimeGap
# 0            59.40    57.500000
# 1           108.48    40.000000
# 2           504.00    16.578947
# 3            39.80    36.375000
# 4           152.64    22.571429
# ...            ...          ...
# 4219         25.50     0.000000
# 4220         34.68     0.000000
# 4221        270.00     0.000000
# 4222        122.40     0.000000
# 4223         71.70     0.000000
#
# [4224 rows x 11 columns]

# %%
Customer_x=pd.merge(Customer_11,Nsessions, how='left',on='Customer ID')

# %%
Customer_11=pd.merge(Customer_x,distinctProd,on='Customer ID')

# %%
Customer_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4224 entries, 0 to 4223
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer ID       4224 non-null   float64
#  1   MeanProdSale      4213 non-null   float64
#  2   TotalSale         4224 non-null   float64
#  3   TotalProd         4224 non-null   int64
#  4   MeanSpentSession  4224 non-null   float64
#  5   MeanProdSession   4224 non-null   float64
#  6   TotalSpentRet     4224 non-null   float64
#  7   TotalProdRet      4224 non-null   int64
#  8   MinProdSpent      4224 non-null   float64
#  9   MaxProdSpent      4224 non-null   float64
#  10  MeanTimeGap       4224 non-null   float64
#  11  Nsessions         4213 non-null   float64
#  12  DistinctProd      4224 non-null   int64
# dtypes: float64(10), int64(3)
# memory usage: 462.0 KB

# %%
Customer_11.loc[Customer_11['MeanProdSale'].isnull(),'MeanProdSale'] = 0

# %%
Customer_11.loc[Customer_11['Nsessions'].isnull(),'Nsessions'] = 0

# %%
Customer_11.to_csv(r'C:\Users\Stefano\Desktop\Data-Mining-Project\dataset\new_Customer_2011.csv', index = False, header=True)

# %%
df = pd.read_csv('../dataset/customer/new_Customer_2011_old.csv', sep=',', index_col=0)

# %%
df_11=df[df['TotalSale']>0]

# %%
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
sn.heatmap(df_11.corr(), annot=True)
plt.show()

# %%
corr_threshold = 0.8
print("Att. A\tAtt. B\tCorr(A,B)")
for i in range(0, len(df_11.columns)):
    for j in range(i+1, len(df_11.columns)):
        corr = df_11[df_11.columns[i]].corr(df_11[df_11.columns[j]])
        if  corr > corr_threshold:
            print(df_11.columns[i] + "\t" + df_11.columns[j] + "\t" + '{:.4f}'.format(corr))
# Out:
# Att. A	Att. B	Corr(A,B)
# TotalSale	TotalProd	0.9226
# TotalSale	TotalSpentRet	0.9986
# TotalProd	TotalSpentRet	0.9217

# %%
corr_columns = ['TotalSpentRet','TotalProd']
df_11.drop(corr_columns, axis=1, inplace=True)
# Out:
# <ipython-input-7-ae9def19982b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_11.drop(corr_columns, axis=1, inplace=True)

# %%
df_11.to_csv(r'C:\Users\Stefano\Desktop\Data-Mining-Project\dataset\customer\new_Customer_2011.csv',header=True)
